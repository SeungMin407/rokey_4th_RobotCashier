# %%
import time
from onrobot import RG

GRIPPER_NAME = 'rg2'
TOOLCHARGER_IP = '192.168.1.1'
TOOLCHARGER_PORT = '502'

grippper = RG(GRIPPER_NAME, TOOLCHARGER_IP, TOOLCHARGER_PORT)

# %%
grippper.close_gripper()
# Out:
# Start closing gripper.

# %%
grippper.open_gripper()
# Out:
# Start opening gripper.

# %%
grippper.move_gripper(30)
# Out:
# Start moving gripper.
